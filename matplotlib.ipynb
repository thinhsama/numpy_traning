# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
# Plotting x and y points
xpoints = np.array([0, 6])
ypoints = np.array([0,250])
print(xpoints, ypoints)
plt.plot(xpoints, ypoints)
plt.show()
# Out:
# [0 6] [  0 250]

# %%
# Plotting Without Line
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
# multiple points
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1 , 10])
plt.plot(xpoints, ypoints)
plt.show()

# %%
# Default X-Points they will get the default values 0, 1, 2, 3 etc.
ypoints = np.array([3, 8, 1, 10, 5, 7])
plt.plot(ypoints)
plt.show()

# %%
# marker
plt.plot(ypoints, marker = 'o')
plt.show()

# %%
# marker
plt.plot(ypoints, marker = 'p')
plt.show()

# %%
# format strings fmt marker|line|color
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o:r')
plt.show()
# line ref = '-', ':', '--', '-.'

# %%
# marker size marker color
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, 'o--r', ms = 20, mec = 'r', mfc = 'b')
plt.show()

# %%
# line style
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, linestyle = 'dotted', linewidth = '20.5')
plt.show()

# %%
# multi line
y1 = np.array([3, 8, 1, 10])
y2 = np.array([6,2,7,11])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
# create labels for a plot, title
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.xlabel('Average Pulse')
plt.ylabel('Calorie Burage')
plt.title('Spot Watch data')
plt.plot(x, y)
plt.show()

# %%
# set font properties for title and labels 
font1 = {'family':'serif','color':'blue','size':20}
font2 = {'family':'serif','color':'darkred','size':15}

plt.title("Sports Watch Data", fontdict = font1, loc = 'left')
plt.xlabel("Average Pulse", fontdict = font2)
plt.ylabel("Calorie Burnage", fontdict = font2)

plt.plot(x, y)
plt.show()

# %%
# adding grid lines
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])
plt.title('Bi')
plt.xlabel('A')
plt.ylabel('B')
plt.plot(x, y)

plt.grid(axis = 'x', color = 'green', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
#subplot
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1,2,1)
plt.plot(x, y)
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 1, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 1, 2)
plt.plot(x,y)

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)
plt.title("INCOME")
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)
plt.title("INCOME")
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(2, 3, 3)
plt.plot(x,y)
plt.title("INCOME")
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)
plt.title("INCOME")
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)
plt.title("INCOME")
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("MY SHOP") # super title
plt.show()

# %%
# scatter
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#day one, the age and speed of 13 cars:
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#day two, the age and speed of 15 cars:
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)

plt.show()

# %%
# color map cmap
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
# bars
x = np.array(['A', 'B', 'C', 'D'])
y = np.array([3, 8, 1, 10])
plt.bar(x, y)
plt.show()

# %%
x = ['Apples', 'Bananas']
y = [300, 500]
plt.subplot(1,2,1)
plt.bar(x, y, color = 'hotpink', width=0.2)
plt.subplot(1,2,2)
plt.barh(x, y, color = 'red', height = 0.1)
plt.show()

# %%
# histogram
#2 people from 140 to 145cm
#5 people from 145 to 150cm
#15 people from 151 to 156cm
#31 people from 157 to 162cm
#46 people from 163 to 168cm
#53 people from 168 to 173cm
#45 people from 173 to 178cm
#28 people from 179 to 184cm
#21 people from 185 to 190cm
#4 people from 190 to 195cm

# hist()
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()

# %%
# pie charts
y = np.array([35, 25, 25, 15])
mylabels = ['A', 'B', 'C', 'D']
myexplode = [0.2, 0, 0, 0]
mycolors = ["black", "hotpink", "b", "#4CAF50"]
plt.pie(y, labels= mylabels, labeldistance=0.5, startangle= 90, explode=myexplode, shadow=True, colors=mycolors)
plt.legend(title = 'Four letter')
plt.show()
